# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df['flower'] = iris.target
df['flower'] = df['flower'].apply(lambda x :iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    flower
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# %%
import numpy as np
kernels = ['rbf','linear']
c = [1,10,20]
avg_score = {}

for kval in kernels:
    for cval in c:
        cv_score = cross_val_score(SVC(kernel=kval,C=cval),iris.data,iris.target,cv=6)
        avg_score[kval + '_' + str(cval)] = np.average(cv_score)

# %%
avg_score
# Out:
# {'rbf_1': 0.98,
#  'rbf_10': 0.98,
#  'rbf_20': 0.96,
#  'linear_1': 0.98,
#  'linear_10': 0.9666666666666667,
#  'linear_20': 0.9666666666666667}

# %%
#another method

# %%
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(SVC(),{
    'C' : [1,10,20,30,50],
    'kernel' : ['rbf','linear']

},cv=6,return_train_score=False)

# %%
clf.fit(iris.data,iris.target)
# Out:
# GridSearchCV(cv=6, estimator=SVC(),
#              param_grid={'C': [1, 10, 20, 30, 50], 'kernel': ['rbf', 'linear']})

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.00081694, 0.00083458, 0.00115919, 0.00066515, 0.00082767,
#         0.00049317, 0.00099655, 0.0008287 , 0.0012027 , 0.00050068]),
#  'std_fit_time': array([3.66605522e-04, 3.73500663e-04, 3.75326531e-04, 4.70331444e-04,
#         6.79035713e-04, 4.93275456e-04, 2.03433446e-06, 3.70619449e-04,
#         4.56620251e-04, 5.00686982e-04]),
#  'mean_score_time': array([0.00100255, 0.00033216, 0.00033744, 0.00033784, 0.00033243,
#         0.00016622, 0.00016626, 0.00083419, 0.00062585, 0.00049337]),
#  'std_score_time': array([0.00058444, 0.00047014, 0.00075454, 0.00047787, 0.00047013,
#         0.00037167, 0.00037176, 0.00037308, 0.00045001, 0.00049349]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30, 50, 50],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
# ...

# %%
df = pd.DataFrame(clf.cv_results_)

# %%
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.000817      0.000367         0.001003        0.000584       1
# 1       0.000835      0.000374         0.000332        0.000470       1
# 2       0.001159      0.000375         0.000337        0.000755      10
# 3       0.000665      0.000470         0.000338        0.000478      10
# 4       0.000828      0.000679         0.000332        0.000470      20
# 5       0.000493      0.000493         0.000166        0.000372      20
# 6       0.000997      0.000002         0.000166        0.000372      30
# 7       0.000829      0.000371         0.000834        0.000373      30
# 8       0.001203      0.000457         0.000626        0.000450      50
# 9       0.000501      0.000501         0.000493        0.000493      50
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}               0.96
# ...

# %%
df[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.980000
# 1       1       linear         0.980000
# 2      10          rbf         0.980000
# 3      10       linear         0.966667
# 4      20          rbf         0.960000
# 5      20       linear         0.966667
# 6      30          rbf         0.960000
# 7      30       linear         0.960000
# 8      50          rbf         0.960000
# 9      50       linear         0.966667

# %%
from sklearn.model_selection import RandomizedSearchCV
rs = RandomizedSearchCV(SVC(),{
    'C':[1,10,20],
    'kernel' : ['rbf','linear']
},cv=6,return_train_score=False,n_iter=3)

# %%
rs.fit(iris.data,iris.target)
# Out:
# RandomizedSearchCV(cv=6, estimator=SVC(), n_iter=3,
#                    param_distributions={'C': [1, 10, 20],
#                                         'kernel': ['rbf', 'linear']})

# %%
pd.DataFrame(rs.cv_results_)[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0      10          rbf             0.98
# 1       1          rbf             0.98
# 2      20          rbf             0.96

# %%
# another method
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
model_params = {
    'svm' : {
        'model':SVC(),
        'param':{
            'C' : [1,10,20],
            'kernel' : ['rbf','linear']
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'param':{
            'n_estimators' : [1,5,10]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(solver='liblinear'),
        'param':{
            'C' : [1,5,10]
        }
    }
}

# %%
scores = []
for model_name,mp in model_params.items():
    clf = GridSearchCV(mp['model'],mp['param'],cv=5,return_train_score=False)
    clf.fit(iris.data,iris.target)
    scores.append({
        'model':model_name,
        'bestscore':clf.best_score_,
        'bestparams':clf.best_params_
    })

# %%
scores
# Out:
# [{'model': 'svm',
#   'bestscore': 0.9800000000000001,
#   'bestparams': {'C': 1, 'kernel': 'linear'}},
#  {'model': 'random_forest',
#   'bestscore': 0.9533333333333334,
#   'bestparams': {'n_estimators': 1}},
#  {'model': 'logistic_regression',
#   'bestscore': 0.9666666666666668,
#   'bestparams': {'C': 5}}]

# %%
df = pd.DataFrame(scores,columns=['model','bestscore','bestparams'])
df
# Out:
#                  model  bestscore                    bestparams
# 0                  svm   0.980000  {'C': 1, 'kernel': 'linear'}
# 1        random_forest   0.953333           {'n_estimators': 1}
# 2  logistic_regression   0.966667                      {'C': 5}
